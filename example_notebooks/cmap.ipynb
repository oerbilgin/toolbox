# %%
import sys
sys.path.insert(0, '/Users/Onur/repos/toolbox/')
from plot_helpers import *
# %matplotlib inline

# %%
fig, ax = plt.subplots()
x = np.linspace(1,15,100)
y = (x - 8)**2
ax.plot(x,y, 'k')
for i, xval in enumerate(x):
    ax.plot([8, xval], [80, y[i]], color=cmap_color(i, len(x)))
